# %%
include("../cliff5.jl")
using PyPlot
using LaTeXStrings
using Profile

# %%
function bw_mbl_update!(state)
    n = size(state, 1)
    for i in 1:2:n
        cl = random_2mbl_gate()
        cliff2_action(cl, state, i, i%n+1)
    end
    for i in 2:2:n
        cl = random_2mbl_gate()
        cliff2_action(cl, state, i, i%n+1)
    end
end
# Out:
# bw_mbl_update! (generic function with 1 method)

# %%
n = 64
n_step = 100
step_size = 1
n_average = 100

state = all_plus(n)
result = zeros(n_step)
cut = div(n, 2)

for _ in 1:n_average
    for t in 1:n_step
        result[t] += pure_state_bipartite_entropy(state, 1:cut)
        bw_mbl_update!(state)
    end
end

result ./= n_average
# Out:
# 100-element Array{Float64,1}:
#  1.05
#  1.06
#  0.99
#  0.98
#  0.89
#  0.97
#  0.99
#  1.01
#  1.11
#  0.92
#  0.86
#  0.99
#  0.98
#  ⋮
#  1.09
#  0.98
#  1.07
#  1.06
#  0.95
#  1.04
#  1.08
#  0.99
#  0.9
#  0.91
#  1.07
#  1.19

# %%
x = 1:n_step
y = result

plot(x, y)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000000253A5E0>
